# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import os
HOME_DIR = os.getcwd()
PWD = os.path.join(HOME_DIR, 'gdrive', 'MyDrive', 'Colab Notebooks', 'CS498', 'assignment4_materials')
print(PWD)
os.chdir(PWD)
# print(HOME_DIR)
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/CS498/assignment4_materials

# %%
# Download celeb data
# !chmod u+rwx download_language.sh
# !./download_language.sh

# %%
# move the zip file to Kontent and unpack
if True:
  import shutil 
  shutil.copyfile("language_data.zip", "/content/language_data.zip")
  os.makedirs('/content/language_data', exist_ok=True)
  # !unzip "/content/language_data.zip" -d "/content/language_data"
# Out:
# Archive:  /content/language_data.zip
#    creating: /content/language_data/language_data/
#   inflating: /content/language_data/__MACOSX/._language_data
#   inflating: /content/language_data/language_data/.DS_Store
#   inflating: /content/language_data/__MACOSX/language_data/._.DS_Store
#    creating: /content/language_data/language_data/test/
#   inflating: /content/language_data/__MACOSX/language_data/._test
#   inflating: /content/language_data/language_data/kaggle_rnn_language_classification_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/._kaggle_rnn_language_classification_test.txt
#    creating: /content/language_data/language_data/train/
#   inflating: /content/language_data/__MACOSX/language_data/._train
#   inflating: /content/language_data/language_data/shakespeare.txt
#   inflating: /content/language_data/__MACOSX/language_data/._shakespeare.txt
#   inflating: /content/language_data/language_data/test/portuguese_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._portuguese_test.txt
#   inflating: /content/language_data/language_data/test/maori_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._maori_test.txt
#   inflating: /content/language_data/language_data/test/german_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._german_test.txt
#   inflating: /content/language_data/language_data/test/lithuanian_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._lithuanian_test.txt
#   inflating: /content/language_data/language_data/test/danish_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._danish_test.txt
#   inflating: /content/language_data/language_data/test/hungarian_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._hungarian_test.txt
#   inflating: /content/language_data/language_data/test/norwegian_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._norwegian_test.txt
#   inflating: /content/language_data/language_data/test/italian_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._italian_test.txt
#   inflating: /content/language_data/language_data/test/romanian_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._romanian_test.txt
#   inflating: /content/language_data/language_data/test/spanish_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._spanish_test.txt
#   inflating: /content/language_data/language_data/test/english_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._english_test.txt
#   inflating: /content/language_data/language_data/test/finnish_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._finnish_test.txt
#   inflating: /content/language_data/language_data/test/vietnamese_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._vietnamese_test.txt
#   inflating: /content/language_data/language_data/test/xhosa_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._xhosa_test.txt
#   inflating: /content/language_data/language_data/test/czech_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._czech_test.txt
#   inflating: /content/language_data/language_data/test/swedish_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._swedish_test.txt
#   inflating: /content/language_data/language_data/test/esperanto_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._esperanto_test.txt
#   inflating: /content/language_data/language_data/test/albanian_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._albanian_test.txt
#   inflating: /content/language_data/language_data/test/french_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._french_test.txt
#   inflating: /content/language_data/language_data/test/turkish_test.txt
#   inflating: /content/language_data/__MACOSX/language_data/test/._turkish_test.txt
#   inflating: /content/language_data/language_data/train/english_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._english_train.txt
#   inflating: /content/language_data/language_data/train/esperanto_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._esperanto_train.txt
#   inflating: /content/language_data/language_data/train/albanian_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._albanian_train.txt
#   inflating: /content/language_data/language_data/train/finnish_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._finnish_train.txt
#   inflating: /content/language_data/language_data/train/spanish_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._spanish_train.txt
#   inflating: /content/language_data/language_data/train/italian_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._italian_train.txt
#   inflating: /content/language_data/language_data/train/lithuanian_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._lithuanian_train.txt
#   inflating: /content/language_data/language_data/train/french_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._french_train.txt
#   inflating: /content/language_data/language_data/train/maori_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._maori_train.txt
#   inflating: /content/language_data/language_data/train/romanian_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._romanian_train.txt
#   inflating: /content/language_data/language_data/train/german_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._german_train.txt
#   inflating: /content/language_data/language_data/train/portuguese_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._portuguese_train.txt
#   inflating: /content/language_data/language_data/train/turkish_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._turkish_train.txt
#   inflating: /content/language_data/language_data/train/swedish_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._swedish_train.txt
#   inflating: /content/language_data/language_data/train/hungarian_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._hungarian_train.txt
#   inflating: /content/language_data/language_data/train/czech_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._czech_train.txt
#   inflating: /content/language_data/language_data/train/vietnamese_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._vietnamese_train.txt
#   inflating: /content/language_data/language_data/train/xhosa_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._xhosa_train.txt
#   inflating: /content/language_data/language_data/train/danish_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._danish_train.txt
#   inflating: /content/language_data/language_data/train/norwegian_train.txt
#   inflating: /content/language_data/__MACOSX/language_data/train/._norwegian_train.txt

# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/9e/25/723487ca2a52ebcee88a34d7d1f5a4b80b793f179ee0f62d5371938dfa01/Unidecode-1.2.0-py2.py3-none-any.whl (241kB)
#      |████████████████████████████████| 245kB 5.3MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.2.0

# %%
import os
import time
import math
import glob
import string
import random 

import torch
import torch.nn as nn

from rnn.helpers import time_since

# %matplotlib inline

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Language recognition with an RNN
#
# If you've ever used an online translator you've probably seen a feature that automatically detects the input language. While this might be easy to do if you input unicode characters that are unique to one or a small group of languages (like "你好" or "γεια σας"), this problem is more challenging if the input only uses the available ASCII characters. In this case, something like "těší mě" would beome "tesi me" in the ascii form. This is a more challenging problem in which the language must be recognized purely by the pattern of characters rather than unique unicode characters.
#
# We will train an RNN to solve this problem for a small set of languages thta can be converted to romanized ASCII form. For training data it would be ideal to have a large and varied dataset in different language styles. However, it is easy to find copies of the Bible which is a large text translated to different languages but in the same easily parsable format, so we will use 20 different copies of the Bible as training data. Using the same book for all of the different languages will hopefully prevent minor overfitting that might arise if we used different books for each language (fitting to common characteristics of the individual books rather than the language).

# %%
from unidecode import unidecode as unicodeToAscii

all_characters = string.printable
n_letters = len(all_characters)

print(unicodeToAscii('těší mě'))
# Out:
# tesi me

# %% [markdown]
# # Utilities

# %%
# Read a file and split into lines
def readFile(filename):
    data = open(filename, encoding='utf-8').read().strip()
    return unicodeToAscii(data)

def get_category_data(data_path):
    # Build the category_data dictionary, a list of names per language
    category_data = {}
    all_categories = []
    for filename in glob.glob(data_path):
        category = os.path.splitext(os.path.basename(filename))[0].split('_')[0]
        all_categories.append(category)
        data = readFile(filename)
        category_data[category] = data
    
    return category_data, all_categories

# %% [markdown]
# The original text is split into two parts, train and test, so that we can make sure that the model is not simply memorizing the train data.

# %%
train_data_path = '/content/language_data/language_data/train/*_train.txt'
test_data_path = '/content/language_data/language_data/test/*_test.txt'

train_category_data, all_categories = get_category_data(train_data_path)
test_category_data, test_all_categories = get_category_data(test_data_path)

n_languages = len(all_categories)

print(len(all_categories))
print(all_categories)
# Out:
# 20
# ['hungarian', 'vietnamese', 'albanian', 'swedish', 'xhosa', 'french', 'italian', 'danish', 'english', 'czech', 'norwegian', 'lithuanian', 'portuguese', 'maori', 'esperanto', 'turkish', 'romanian', 'spanish', 'german', 'finnish']

# %% [markdown]
# # Data processing

# %%
def categoryFromOutput(output):
    top_n, top_i = output.topk(1, dim=1)
    category_i = top_i[:, 0]
    return category_i

# Turn string into long tensor
def stringToTensor(string):
    tensor = torch.zeros(len(string), requires_grad=True).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return tensor

def load_random_batch(text, chunk_len, batch_size):
    input_data = torch.zeros(batch_size, chunk_len).long().to(device)
    target = torch.zeros(batch_size, 1).long().to(device)
    input_text = []
    for i in range(batch_size):
        category = all_categories[random.randint(0, len(all_categories) - 1)]
        line_start = random.randint(0, len(text[category])-chunk_len)
        category_tensor = torch.tensor([all_categories.index(category)], dtype=torch.long)
        line = text[category][line_start:line_start+chunk_len]
        input_text.append(line)
        input_data[i] = stringToTensor(line)
        target[i] = category_tensor
    return input_data, target, input_text

# %% [markdown]
# Implement Model
# ====================
#
# For this classification task, we can use the same model we implement for the generation task which is located in `rnn/model.py`. See the `MP4_P2_generation.ipynb` notebook for more instructions. In this case each output vector of our RNN will have the dimension of the number of possible languages (i.e. `n_languages`). We will use this vector to predict a distribution over the languages.
#
# In the generation task, we used the output of the RNN at every time step to predict the next letter and our loss included the output from each of these predictions. However, in this task we use the output of the RNN at the end of the sequence to predict the language, so our loss function will use only the predicted output from the last time step.

# %% [markdown]
# # Train RNN

# %%
from rnn.model import RNN

# %%
chunk_len = 50

BATCH_SIZE = 128
# n_epochs = 2000
hidden_size = 128
n_layers = 2
# n_layers = 1
# learning_rate = 0.01
model_type = 'gru'

criterion = nn.CrossEntropyLoss()
rnn = RNN(n_letters, hidden_size, n_languages, model_type=model_type, n_layers=n_layers).to(device)

# %% [markdown]
# **TODO:** Fill in the train function. You should initialize a hidden layer representation using your RNN's `init_hidden` function, set the model gradients to zero, and loop over each time step (character) in the input tensor. For each time step compute the output of the of the RNN and the next hidden layer representation. The cross entropy loss should be computed over the last RNN output scores from the end of the sequence and the target classification tensor. Lastly, call backward on the loss and take an optimizer step.

# %%
def train(rnn, target_tensor, data_tensor, optimizer, criterion, batch_size=BATCH_SIZE):
    """
    Inputs:
    - rnn: model
    - target_target: target character data tensor of shape (batch_size, 1)
    - data_tensor: input character data tensor of shape (batch_size, chunk_len)
    - optimizer: rnn model optimizer
    - criterion: loss function
    - batch_size: data batch size
    
    Returns:
    - output: output from RNN from end of sequence 
    - loss: computed loss value as python float
    
    """    
    output, loss = None, None
    
    rnn.train()
    hidden = rnn.init_hidden(batch_size = batch_size, device = data_tensor.device)
    optimizer.zero_grad()

    # batch_size = data_tensor.size()[0]
    chunk_len = data_tensor.size()[1]

    ####################################
    #          YOUR CODE HERE          #
    ####################################
    for c in range(chunk_len):
      output, hidden = rnn(data_tensor[:,c], hidden)

    loss = criterion(output, target_tensor.view(-1))   
    loss.backward()
    optimizer.step()
    ##########       END      ##########

    return output, loss.data.item()

# %%
def evaluate(rnn, data_tensor, seq_len=chunk_len, batch_size=BATCH_SIZE):
    with torch.no_grad():
        data_tensor = data_tensor.to(device)
        hidden = rnn.init_hidden(batch_size, device=device)
        for i in range(seq_len):
            output, hidden = rnn(data_tensor[:,i], hidden)
        
        return output
    
def eval_test(rnn, category_tensor, data_tensor):
    with torch.no_grad():
        output = evaluate(rnn, data_tensor)
        loss = criterion(output, category_tensor.squeeze())
        return output, loss.item()

# %% [markdown]
# ## Training
# We do the training here. For brevity, the code + output is skipped, please see the attached notebook for code details.

# %%
n_iters = 1000 #2000 #100000
print_every = 50
plot_every = 50


# Keep track of losses for plotting
current_loss = 0
current_test_loss = 0
all_losses = []
all_test_losses = []

start = time.time()

learning_rate = 0.0001
optimizer = torch.optim.Adam(rnn.parameters(), lr=learning_rate)


number_correct = 0
for iter in range(1, n_iters + 1):
    input_data, target_category, text_data = load_random_batch(train_category_data, chunk_len, BATCH_SIZE)
    output, loss = train(rnn, target_category, input_data, optimizer, criterion)
    current_loss += loss
    rnn.eval()
    _, test_loss = eval_test(rnn, target_category, input_data)
    current_test_loss += test_loss
    
    guess_i = categoryFromOutput(output)
    number_correct += (target_category.squeeze()==guess_i.squeeze()).long().sum()


    # Print iter number, loss, name and guess
    if iter % print_every == 0:
        sample_idx = 0
        guess = all_categories[guess_i[sample_idx]]
        
        category = all_categories[int(target_category[sample_idx])]

        if True:
          test_input_data, test_target_category, test_text_data = load_random_batch(test_category_data, chunk_len, BATCH_SIZE)
          test_output, _ = eval_test(rnn, test_target_category, test_input_data)
          test_guess_i = categoryFromOutput(test_output)
          test_number_correct = (test_target_category.squeeze()==test_guess_i.squeeze()).long().sum()

        correct = '✓' if guess == category else '✗ (%s)' % category
        print('%d %d%% (%s) %.4f %.4f %s / %s %s' % (iter, iter / n_iters * 100, time_since(start), loss, test_loss, text_data[sample_idx], guess, correct))
        print('Train accuracy: {}'.format(float(number_correct)/float(print_every*BATCH_SIZE)))
        print('Test accuracy: {}'.format(float(test_number_correct)/float(BATCH_SIZE)))
        number_correct = 0
    
    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        all_losses.append(current_loss / plot_every)
        current_loss = 0
        all_test_losses.append(current_test_loss / plot_every)
        current_test_loss = 0
# Out:
# 50 5% (0m 19s) 0.0288 0.0270 hor. Levantemos os nossos coracoes com as maos par / portuguese ✓
# Train accuracy: 0.9959375
# Test accuracy: 1.0
# 100 10% (0m 38s) 0.0024 0.0023 uba ndinindulula nina nentsapho yenu. Khangelani,  / xhosa ✓
# Train accuracy: 0.995625
# Test accuracy: 1.0
# 150 15% (0m 57s) 0.0077 0.0075 rt e Ponc Pilatit, guvernatorit. Atehere Juda, qe  / albanian ✓
# Train accuracy: 0.99546875
# Test accuracy: 0.9921875
# 200 20% (1m 16s) 0.0494 0.0491 l und ein verdrehtes Maul hasse ich. Von mir kommt / german ✓
# Train accuracy: 0.99515625
# Test accuracy: 0.984375
# 250 25% (1m 35s) 0.0037 0.0037 n saanut nimekseen Mara. Kansa nurisi Moosesta vas / finnish ✓
# Train accuracy: 0.9959375
# Test accuracy: 0.9921875
# 300 30% (1m 54s) 0.0077 0.0075  biet nhung y tuong trong long minh. Hoi vua, vua  / vietnamese ✓
# Train accuracy: 0.995
# Test accuracy: 0.9921875
# 350 35% (2m 13s) 0.0145 0.0136 xsxon, filo de Aminadab, de la tribo de Jehuda. Ka / esperanto ✓
# Train accuracy: 0.99546875
# Test accuracy: 1.0
# 400 40% (2m 32s) 0.0238 0.0226 it Ezdra, shkruesit, nje shkrues kompetent ne urdh / albanian ✓
# Train accuracy: 0.99484375
# Test accuracy: 1.0
# 450 45% (2m 51s) 0.0240 0.0227 j Balak,  filo de Cipor, estis regxo de Moab en ti / esperanto ✓
# Train accuracy: 0.99390625
# Test accuracy: 0.984375
# 500 50% (3m 10s) 0.0056 0.0054  ai. Ko te haerenga mai tera o nga rangatira katoa / maori ✓
# Train accuracy: 0.995625
# Test accuracy: 0.9921875
# 550 55% (3m 30s) 0.0307 0.0293 mane ir tarnavote svetimiems dievams. Todel daugia / lithuanian ✓
# Train accuracy: 0.99578125
# Test accuracy: 0.9921875
# 600 60% (3m 49s) 0.0139 0.0106  were eyes like the eyes of a man, and a mouth spe / english ✓
# Train accuracy: 0.99484375
# Test accuracy: 1.0
# 650 65% (4m 8s) 0.0005 0.0005  statutet dhe dekretet e mia dhe do t'i vini ne zb / albanian ✓
# Train accuracy: 0.99328125
# Test accuracy: 0.984375
# 700 70% (4m 27s) 0.0052 0.0051 mi otroky a odvadeli davky. Hospodin Davida zachra / czech ✓
# Train accuracy: 0.99546875
# Test accuracy: 0.9921875
# 750 75% (4m 46s) 0.0270 0.0257  kisileri<br />RAB basina yonetici atayinca ne diy / turkish ✓
# Train accuracy: 0.995
# Test accuracy: 0.984375
# 800 80% (5m 4s) 0.0085 0.0084 anak az Aseraknak es balvanyoknak; mely vetkok mia / hungarian ✓
# Train accuracy: 0.9940625
# Test accuracy: 0.984375
# 850 85% (5m 23s) 0.0231 0.0225 ia, vua som mai chung di ra lam cong viec minh, Ti / vietnamese ✓
# Train accuracy: 0.99546875
# Test accuracy: 0.9921875
# 900 90% (5m 42s) 0.0276 0.0262 . Und lege sie in die Stiftshutte vor das Zeugnis, / german ✓
# Train accuracy: 0.994375
# Test accuracy: 0.9921875
# 950 95% (6m 1s) 0.0155 0.0148 am meget, og han sagde: "Lovet vaere HERREN i dag, / danish ✓
# Train accuracy: 0.9940625
# Test accuracy: 0.9921875
# 1000 100% (6m 21s) 0.0025 0.0025 inach, nezbude nic zeleneho. Proto zbytek toho, na / czech ✓
# Train accuracy: 0.99453125
# Test accuracy: 0.9921875

# %% [markdown]
# Plot loss functions
# --------------------

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure()
plt.plot(all_losses, color='b')
plt.plot(all_test_losses, color='r')

# %% [markdown]
# Evaluate results
# -------------------
#
# We now vizualize the performance of our model by creating a confusion matrix. The ground truth languages of samples are represented by rows in the matrix while the predicted languages are represented by columns.
#
# In this evaluation we consider sequences of variable sizes rather than the fixed length sequences we used for training.

# %%
eval_batch_size = 1  # needs to be set to 1 for evaluating different sequence lengths

# Keep track of correct guesses in a confusion matrix
confusion = torch.zeros(n_languages, n_languages)
n_confusion = 1000
num_correct = 0
total = 0

for i in range(n_confusion):
    eval_chunk_len = random.randint(10, 50) # in evaluation we will look at sequences of variable sizes
    input_data, target_category, text_data = load_random_batch(test_category_data, chunk_len=eval_chunk_len, batch_size=eval_batch_size)
    output = evaluate(rnn, input_data, seq_len=eval_chunk_len, batch_size=eval_batch_size)
    
    guess_i = categoryFromOutput(output)
    category_i = [int(target_category[idx]) for idx in range(len(target_category))]
    for j in range(eval_batch_size):
        category = all_categories[category_i[j]] 
        confusion[category_i[j]][guess_i[j]] += 1
        num_correct += int(guess_i[j]==category_i[j])
        total += 1

print('Test accuracy: ', float(num_correct)/float(n_confusion*eval_batch_size))

# Normalize by dividing every row by its sum
for i in range(n_languages):
    confusion[i] = confusion[i] / confusion[i].sum()

# Set up plot
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(confusion.numpy())
fig.colorbar(cax)

# Set up axes
ax.set_xticklabels([''] + all_categories, rotation=90)
ax.set_yticklabels([''] + all_categories)

# Force label at every tick
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

plt.show()
# Out:
# Test accuracy:  0.918

# %% [markdown]
# You can pick out bright spots off the main axis that show which
# languages it guesses incorrectly.

# %% [markdown]
# Run on User Input
# ---------------------
#
# Now you can test your model on your own input.

# %%
def predict(input_line, n_predictions=5):
    print('\n> %s' % input_line)
    with torch.no_grad():
        input_data = stringToTensor(input_line).long().unsqueeze(0).to(device)
        output = evaluate(rnn, input_data, seq_len=len(input_line), batch_size=1)

    # Get top N categories
    topv, topi = output.topk(n_predictions, dim=1)
    predictions = []

    for i in range(n_predictions):
        topv.shape
        topi.shape
        value = topv[0][i].item()
        category_index = topi[0][i].item()
        print('(%.2f) %s' % (value, all_categories[category_index]))
        predictions.append([value, all_categories[category_index]])

predict('This is a phrase to test the model on user input')
# Out:
# > This is a phrase to test the model on user input
# (12.88) english
# (4.38) albanian
# (2.99) danish
# (2.21) czech
# (1.67) italian

# %% [markdown]
# # Output Kaggle submission file
#
# Once you have found a good set of hyperparameters submit the output of your model on the Kaggle test file.

# %%
### DO NOT CHANGE KAGGLE SUBMISSION CODE ####
import csv

kaggle_test_file_path = '/content/language_data/language_data/kaggle_rnn_language_classification_test.txt'
with open(kaggle_test_file_path, 'r') as f:
    lines = f.readlines()

output_rows = []
for i, line in enumerate(lines):
    sample = line.rstrip()
    sample_chunk_len = len(sample)
    input_data = stringToTensor(sample).unsqueeze(0)
    output = evaluate(rnn, input_data, seq_len=sample_chunk_len, batch_size=1)
    guess_i = categoryFromOutput(output)
    output_rows.append((str(i+1), all_categories[guess_i]))

submission_file_path = 'kaggle_rnn_submission.txt'
with open(submission_file_path, 'w') as f:
    output_rows = [('id', 'category')] + output_rows
    writer = csv.writer(f)
    writer.writerows(output_rows)

# %%
# !cat kaggle_rnn_submission.txt
# Out:
# id,category
# 1,norwegian
# 2,turkish
# 3,maori
# 4,french
# 5,maori
# 6,danish
# 7,turkish
# 8,finnish
# 9,portuguese
# 10,english
# 11,esperanto
# 12,turkish
# 13,hungarian
# 14,swedish
# 15,spanish
# 16,turkish
# 17,lithuanian
# 18,turkish
# 19,xhosa
# 20,esperanto
# 21,italian
# 22,french
# 23,norwegian
# 24,lithuanian
# 25,swedish
# 26,hungarian
# 27,english
# 28,finnish
# 29,xhosa
# 30,romanian
# 31,norwegian
# 32,french
# 33,portuguese
# 34,maori
# 35,french
# 36,german
# 37,french
# 38,esperanto
# 39,hungarian
# 40,romanian
# 41,xhosa
# 42,norwegian
# 43,esperanto
# 44,maori
# 45,danish
# 46,portuguese
# 47,english
# 48,albanian
# 49,swedish
# 50,vietnamese
# 51,czech
# 52,esperanto
# 53,danish
# 54,vietnamese
# 55,english
# 56,lithuanian
# 57,norwegian
# 58,spanish
# 59,xhosa
# 60,turkish
# 61,lithuanian
# 62,hungarian
# 63,turkish
# 64,turkish
# 65,norwegian
# 66,lithuanian
# 67,norwegian
# 68,english
# 69,finnish
# 70,lithuanian
# 71,turkish
# 72,albanian
# 73,czech
# 74,english
# 75,english
# 76,esperanto
# 77,finnish
# 78,turkish
# 79,hungarian
# 80,german
# 81,turkish
# 82,maori
# 83,norwegian
# 84,french
# 85,vietnamese
# 86,spanish
# 87,hungarian
# 88,esperanto
# 89,norwegian
# 90,romanian
# 91,italian
# 92,hungarian
# 93,xhosa
# 94,portuguese
# 95,swedish
# 96,norwegian
# 97,norwegian
# 98,swedish
# 99,french
# 100,spanish
# 101,czech
# 102,italian
# 103,xhosa
# 104,xhosa
# 105,italian
# 106,portuguese
# 107,albanian
# 108,romanian
# 109,norwegian
# 110,esperanto
# 111,portuguese
# 112,romanian
# 113,french
# 114,hungarian
# 115,italian
# 116,french
# 117,romanian
# 118,xhosa
# 119,spanish
# 120,french
# 121,hungarian
# 122,maori
# 123,danish
# 124,danish
# 125,danish
# 126,turkish
# 127,portuguese
# 128,hungarian
# 129,danish
# 130,xhosa
# 131,vietnamese
# 132,norwegian
# 133,hungarian
# 134,german
# 135,vietnamese
# 136,norwegian
# 137,czech
# 138,norwegian
# 139,vietnamese
# 140,danish
# 141,xhosa
# 142,esperanto
# 143,czech
# 144,danish
# 145,albanian
# 146,esperanto
# 147,turkish
# 148,portuguese
# 149,french
# 150,maori
# 151,maori
# 152,portuguese
# 153,spanish
# 154,french
# 155,lithuanian
# 156,spanish
# 157,swedish
# 158,danish
# 159,albanian
# 160,romanian
# 161,norwegian
# 162,finnish
# 163,portuguese
# 164,turkish
# 165,danish
# 166,vietnamese
# 167,finnish
# 168,portuguese
# 169,hungarian
# 170,vietnamese
# 171,portuguese
# 172,romanian
# 173,portuguese
# 174,italian
# 175,swedish
# 176,lithuanian
# 177,hungarian
# 178,norwegian
# 179,romanian
# 180,turkish
# 181,french
# 182,hungarian
# 183,finnish
# 184,czech
# 185,romanian
# 186,maori
# 187,swedish
# 188,hungarian
# 189,lithuanian
# 190,czech
# 191,french
# 192,lithuanian
# 193,portuguese
# 194,finnish
# 195,norwegian
# 196,turkish
# 197,lithuanian
# 198,norwegian
# 199,swedish
# 200,german
# 201,czech
# 202,portuguese
# 203,xhosa
# 204,lithuanian
# 205,german
# 206,finnish
# 207,xhosa
# 208,danish
# 209,hungarian
# 210,portuguese
# 211,albanian
# 212,spanish
# 213,turkish
# 214,swedish
# 215,norwegian
# 216,romanian
# 217,norwegian
# 218,czech
# 219,maori
# 220,esperanto
# 221,german
# 222,portuguese
# 223,albanian
# 224,italian
# 225,romanian
# 226,xhosa
# 227,czech
# 228,french
# 229,turkish
# 230,portuguese
# 231,esperanto
# 232,english
# 233,english
# 234,french
# 235,german
# 236,norwegian
# 237,portuguese
# 238,italian
# 239,portuguese
# 240,swedish
# 241,turkish
# 242,xhosa
# 243,albanian
# 244,xhosa
# 245,esperanto
# 246,vietnamese
# 247,maori
# 248,czech
# 249,norwegian
# 250,french
# 251,swedish
# 252,portuguese
# 253,swedish
# 254,vietnamese
# 255,vietnamese
# 256,danish
# 257,romanian
# 258,finnish
# 259,xhosa
# 260,lithuanian
# 261,portuguese
# 262,romanian
# 263,turkish
# 264,turkish
# 265,finnish
# 266,lithuanian
# 267,albanian
# 268,turkish
# 269,italian
# 270,lithuanian
# 271,english
# 272,portuguese
# 273,danish
# 274,czech
# 275,hungarian
# 276,romanian
# 277,english
# 278,finnish
# 279,albanian
# 280,hungarian
# 281,romanian
# 282,norwegian
# 283,maori
# 284,norwegian
# 285,swedish
# 286,hungarian
# 287,english
# 288,albanian
# 289,xhosa
# 290,vietnamese
# 291,czech
# 292,xhosa
# 293,italian
# 294,esperanto
# 295,danish
# 296,spanish
# 297,romanian
# 298,english
# 299,portuguese
# 300,czech
# 301,hungarian
# 302,vietnamese
# 303,albanian
# 304,norwegian
# 305,spanish
# 306,portuguese
# 307,french
# 308,turkish
# 309,turkish
# 310,french
# 311,albanian
# 312,czech
# 313,romanian
# 314,turkish
# 315,portuguese
# 316,portuguese
# 317,czech
# 318,finnish
# 319,vietnamese
# 320,swedish
# 321,spanish
# 322,italian
# 323,esperanto
# 324,esperanto
# 325,albanian
# 326,german
# 327,english
# 328,esperanto
# 329,danish
# 330,portuguese
# 331,vietnamese
# 332,finnish
# 333,turkish
# 334,esperanto
# 335,swedish
# 336,turkish
# 337,xhosa
# 338,italian
# 339,xhosa
# 340,albanian
# 341,turkish
# 342,maori
# 343,romanian
# 344,hungarian
# 345,norwegian
# 346,czech
# 347,maori
# 348,swedish
# 349,albanian
# 350,esperanto
# 351,portuguese
# 352,lithuanian
# 353,vietnamese
# 354,german
# 355,german
# 356,czech
# 357,xhosa
# 358,esperanto
# 359,lithuanian
# 360,norwegian
# 361,english
# 362,portuguese
# 363,turkish
# 364,albanian
# 365,albanian
# 366,finnish
# 367,maori
# 368,spanish
# 369,finnish
# 370,hungarian
# 371,portuguese
# 372,danish
# 373,danish
# 374,czech
# 375,maori
# 376,norwegian
# 377,maori
# 378,danish
# 379,french
# 380,albanian
# 381,xhosa
# 382,albanian
# 383,danish
# 384,maori
# 385,swedish
# 386,vietnamese
# 387,maori
# 388,french
# 389,esperanto
# 390,portuguese
# 391,finnish
# 392,italian
# 393,italian
# 394,turkish
# 395,finnish
# 396,finnish
# 397,english
# 398,maori
# 399,english
# 400,esperanto
# 401,english
# 402,vietnamese
# 403,albanian
# 404,maori
# 405,xhosa
# 406,german
# 407,german
# 408,finnish
# 409,danish
# 410,vietnamese
# 411,danish
# 412,turkish
# 413,esperanto
# 414,danish
# 415,italian
# 416,french
# 417,czech
# 418,lithuanian
# 419,esperanto
# 420,vietnamese
# 421,norwegian
# 422,french
# 423,norwegian
# 424,portuguese
# 425,german
# 426,turkish
# 427,german
# 428,norwegian
# 429,maori
# 430,turkish
# 431,maori
# 432,lithuanian
# 433,portuguese
# 434,french
# 435,norwegian
# 436,turkish
# 437,xhosa
# 438,lithuanian
# 439,italian
# 440,spanish
# 441,xhosa
# 442,norwegian
# 443,french
# 444,english
# 445,xhosa
# 446,english
# 447,french
# 448,norwegian
# 449,norwegian
# 450,czech
# 451,maori
# 452,esperanto
# 453,danish
# 454,vietnamese
# 455,czech
# 456,czech
# 457,german
# 458,hungarian
# 459,lithuanian
# 460,hungarian
# 461,swedish
# 462,hungarian
# 463,maori
# 464,lithuanian
# 465,finnish
# 466,hungarian
# 467,vietnamese
# 468,czech
# 469,albanian
# 470,lithuanian
# 471,albanian
# 472,xhosa
# 473,swedish
# 474,czech
# 475,romanian
# 476,lithuanian
# 477,german
# 478,turkish
# 479,turkish
# 480,hungarian
# 481,portuguese
# 482,italian
# 483,romanian
# 484,romanian
# 485,xhosa
# 486,xhosa
# 487,portuguese
# 488,lithuanian
# 489,romanian
# 490,portuguese
# 491,finnish
# 492,lithuanian
# 493,italian
# 494,esperanto
# 495,romanian
# 496,english
# 497,xhosa
# 498,german
# 499,portuguese
# 500,danish
# 501,romanian
# 502,german
# 503,norwegian
# 504,portuguese
# 505,italian
# 506,english
# 507,english
# 508,french
# 509,xhosa
# 510,hungarian
# 511,romanian
# 512,vietnamese
# 513,turkish
# 514,vietnamese
# 515,norwegian
# 516,german
# 517,italian
# 518,vietnamese
# 519,turkish
# 520,danish
# 521,finnish
# 522,portuguese
# 523,french
# 524,albanian
# 525,danish
# 526,albanian
# 527,german
# 528,albanian
# 529,norwegian
# 530,norwegian
# 531,english
# 532,turkish
# 533,norwegian
# 534,xhosa
# 535,italian
# 536,romanian
# 537,german
# 538,french
# 539,lithuanian
# 540,italian
# 541,romanian
# 542,esperanto
# 543,danish
# 544,spanish
# 545,french
# 546,hungarian
# 547,albanian
# 548,hungarian
# 549,norwegian
# 550,french
# 551,english
# 552,hungarian
# 553,swedish
# 554,portuguese
# 555,swedish
# 556,hungarian
# 557,xhosa
# 558,french
# 559,albanian
# 560,maori
# 561,swedish
# 562,romanian
# 563,czech
# 564,esperanto
# 565,lithuanian
# 566,portuguese
# 567,english
# 568,swedish
# 569,czech
# 570,czech
# 571,english
# 572,german
# 573,czech
# 574,norwegian
# 575,lithuanian
# 576,lithuanian
# 577,norwegian
# 578,vietnamese
# 579,turkish
# 580,spanish
# 581,esperanto
# 582,maori
# 583,portuguese
# 584,portuguese
# 585,esperanto
# 586,romanian
# 587,lithuanian
# 588,turkish
# 589,albanian
# 590,german
# 591,czech
# 592,english
# 593,esperanto
# 594,lithuanian
# 595,maori
# 596,xhosa
# 597,english
# 598,hungarian
# 599,french
# 600,vietnamese
# 601,german
# 602,portuguese
# 603,romanian
# 604,esperanto
# 605,english
# 606,swedish
# 607,italian
# 608,hungarian
# 609,vietnamese
# 610,portuguese
# 611,czech
# 612,turkish
# 613,english
# 614,turkish
# 615,hungarian
# 616,maori
# 617,danish
# 618,hungarian
# 619,hungarian
# 620,albanian
# 621,norwegian
# 622,italian
# 623,esperanto
# 624,german
# 625,french
# 626,maori
# 627,swedish
# 628,english
# 629,italian
# 630,vietnamese
# 631,vietnamese
# 632,romanian
# 633,maori
# 634,german
# 635,portuguese
# 636,german
# 637,danish
# 638,romanian
# 639,albanian
# 640,turkish
# 641,czech
# 642,turkish
# 643,turkish
# 644,norwegian
# 645,hungarian
# 646,esperanto
# 647,danish
# 648,italian
# 649,czech
# 650,albanian
# 651,german
# 652,portuguese
# 653,swedish
# 654,english
# 655,turkish
# 656,turkish
# 657,italian
# 658,czech
# 659,esperanto
# 660,lithuanian
# 661,italian
# 662,swedish
# 663,french
# 664,finnish
# 665,lithuanian
# 666,french
# 667,esperanto
# 668,maori
# 669,norwegian
# 670,norwegian
# 671,hungarian
# 672,czech
# 673,spanish
# 674,french
# 675,vietnamese
# 676,xhosa
# 677,danish
# 678,spanish
# 679,lithuanian
# 680,albanian
# 681,albanian
# 682,danish
# 683,german
# 684,romanian
# 685,czech
# 686,czech
# 687,danish
# 688,english
# 689,vietnamese
# 690,albanian
# 691,swedish
# 692,esperanto
# 693,hungarian
# 694,vietnamese
# 695,swedish
# 696,english
# 697,danish
# 698,danish
# 699,romanian
# 700,romanian
# 701,xhosa
# 702,finnish
# 703,french
# 704,lithuanian
# 705,czech
# 706,swedish
# 707,danish
# 708,swedish
# 709,german
# 710,italian
# 711,swedish
# 712,romanian
# 713,xhosa
# 714,esperanto
# 715,danish
# 716,spanish
# 717,turkish
# 718,italian
# 719,norwegian
# 720,finnish
# 721,french
# 722,finnish
# 723,english
# 724,spanish
# 725,czech
# 726,swedish
# 727,turkish
# 728,german
# 729,romanian
# 730,albanian
# 731,turkish
# 732,esperanto
# 733,portuguese
# 734,czech
# 735,esperanto
# 736,lithuanian
# 737,albanian
# 738,esperanto
# 739,albanian
# 740,portuguese
# 741,esperanto
# 742,turkish
# 743,vietnamese
# 744,hungarian
# 745,norwegian
# 746,danish
# 747,romanian
# 748,albanian
# 749,english
# 750,maori
# 751,swedish
# 752,norwegian
# 753,romanian
# 754,french
# 755,vietnamese
# 756,french
# 757,lithuanian
# 758,danish
# 759,turkish
# 760,german
# 761,italian
# 762,lithuanian
# 763,czech
# 764,spanish
# 765,romanian
# 766,lithuanian
# 767,albanian
# 768,danish
# 769,french
# 770,albanian
# 771,turkish
# 772,albanian
# 773,norwegian
# 774,hungarian
# 775,romanian
# 776,hungarian
# 777,albanian
# 778,french
# 779,finnish
# 780,portuguese
# 781,french
# 782,vietnamese
# 783,czech
# 784,albanian
# 785,xhosa
# 786,xhosa
# 787,czech
# 788,finnish
# 789,romanian
# 790,albanian
# 791,turkish
# 792,hungarian
# 793,finnish
# 794,norwegian
# 795,portuguese
# 796,lithuanian
# 797,turkish
# 798,czech
# 799,albanian
# 800,english
# 801,spanish
# 802,swedish
# 803,finnish
# 804,albanian
# 805,romanian
# 806,hungarian
# 807,albanian
# 808,italian
# 809,spanish
# 810,german
# 811,albanian
# 812,lithuanian
# 813,xhosa
# 814,lithuanian
# 815,esperanto
# 816,maori
# 817,swedish
# 818,romanian
# 819,german
# 820,romanian
# 821,vietnamese
# 822,maori
# 823,turkish
# 824,albanian
# 825,maori
# 826,portuguese
# 827,vietnamese
# 828,romanian
# 829,hungarian
# 830,vietnamese
# 831,portuguese
# 832,lithuanian
# 833,italian
# 834,czech
# 835,portuguese
# 836,esperanto
# 837,spanish
# 838,norwegian
# 839,esperanto
# 840,german
# 841,albanian
# 842,french
# 843,esperanto
# 844,xhosa
# 845,albanian
# 846,hungarian
# 847,portuguese
# 848,esperanto
# 849,czech
# 850,english
# 851,danish
# 852,english
# 853,german
# 854,romanian
# 855,czech
# 856,french
# 857,swedish
# 858,czech
# 859,esperanto
# 860,norwegian
# 861,romanian
# 862,finnish
# 863,xhosa
# 864,italian
# 865,lithuanian
# 866,french
# 867,lithuanian
# 868,vietnamese
# 869,german
# 870,german
# 871,hungarian
# 872,xhosa
# 873,vietnamese
# 874,italian
# 875,finnish
# 876,english
# 877,vietnamese
# 878,turkish
# 879,german
# 880,romanian
# 881,romanian
# 882,hungarian
# 883,romanian
# 884,czech
# 885,esperanto
# 886,maori
# 887,esperanto
# 888,romanian
# 889,romanian
# 890,spanish
# 891,vietnamese
# 892,german
# 893,italian
# 894,finnish
# 895,turkish
# 896,romanian
# 897,maori
# 898,albanian
# 899,finnish
# 900,hungarian
# 901,french
# 902,finnish
# 903,finnish
# 904,czech
# 905,albanian
# 906,danish
# 907,danish
# 908,romanian
# 909,italian
# 910,vietnamese
# 911,xhosa
# 912,albanian
# 913,esperanto
# 914,spanish
# 915,norwegian
# 916,romanian
# 917,hungarian
# 918,swedish
# 919,french
# 920,italian
# 921,maori
# 922,german
# 923,maori
# 924,romanian
# 925,maori
# 926,spanish
# 927,swedish
# 928,maori
# 929,french
# 930,french
# 931,xhosa
# 932,danish
# 933,czech
# 934,esperanto
# 935,maori
# 936,xhosa
# 937,spanish
# 938,portuguese
# 939,norwegian
# 940,finnish
# 941,xhosa
# 942,swedish
# 943,lithuanian
# 944,finnish
# 945,hungarian
# 946,maori
# 947,german
# 948,czech
# 949,german
# 950,norwegian
# 951,romanian
# 952,norwegian
# 953,lithuanian
# 954,romanian
# 955,swedish
# 956,english
# 957,german
# 958,turkish
# 959,italian
# 960,german
# 961,turkish
# 962,norwegian
# 963,spanish
# 964,norwegian
# 965,english
# 966,esperanto
# 967,danish
# 968,czech
# 969,vietnamese
# 970,hungarian
# 971,french
# 972,hungarian
# 973,vietnamese
# 974,maori
# 975,romanian
# 976,esperanto
# 977,english
# 978,portuguese
# 979,swedish
# 980,english
# 981,esperanto
# 982,lithuanian
# 983,french
# 984,swedish
# 985,czech
# 986,german
# 987,finnish
# 988,lithuanian
# 989,german
# 990,esperanto
# 991,norwegian
# 992,turkish
# 993,danish
# 994,romanian
# 995,albanian
# 996,french
# 997,hungarian
# 998,finnish
# 999,italian
# 1000,romanian
# 1001,spanish
# 1002,norwegian
# 1003,spanish
# 1004,maori
# 1005,xhosa
# 1006,maori
# 1007,french
# 1008,portuguese
# 1009,norwegian
# 1010,german
# 1011,french
# 1012,czech
# 1013,portuguese
# 1014,english
# 1015,swedish
# 1016,french
# 1017,albanian
# 1018,romanian
# 1019,spanish
# 1020,turkish
# 1021,vietnamese
# 1022,finnish
# 1023,spanish
# 1024,finnish
# 1025,xhosa
# 1026,esperanto
# 1027,lithuanian
# 1028,hungarian
# 1029,italian
# 1030,xhosa
# 1031,albanian
# 1032,portuguese
# 1033,finnish
# 1034,norwegian
# 1035,romanian
# 1036,romanian
# 1037,french
# 1038,vietnamese
# 1039,xhosa
# 1040,english
# 1041,spanish
# 1042,turkish
# 1043,spanish
# 1044,czech
# 1045,portuguese
# 2948,hungarian
# 2949,turkish
# 2950,romanian
# 2951,esperanto
# 2952,finnish
# 2953,esperanto
# 2954,albanian
# 2955,czech
# 2956,swedish
# 2957,finnish
# 2958,lithuanian
# 2959,hungarian
# 2960,hungarian
# 2961,vietnamese
# 2962,albanian
# 2963,vietnamese
# 2964,esperanto
# 2965,french
# 2966,french
# 2967,finnish
# 2968,vietnamese
# 2969,esperanto
# 2970,albanian
# 2971,danish
# 2972,romanian
# 2973,portuguese
# 2974,english
# 2975,vietnamese
# 2976,lithuanian
# 2977,czech
# 2978,danish
# 2979,danish
# 2980,portuguese
# 2981,vietnamese
# 2982,danish
# 2983,swedish
# 2984,lithuanian
# 2985,romanian
# 2986,czech
# 2987,finnish
# 2988,xhosa
# 2989,spanish
# 2990,norwegian
# 2991,xhosa
# 2992,portuguese
# 2993,xhosa
# 2994,hungarian
# 2995,english
# 2996,german
# 2997,finnish
# 2998,norwegian
# 2999,xhosa
# 3000,esperanto
# 3001,vietnamese
# 3002,french
# 3003,danish
# 3004,norwegian
# 3005,vietnamese
# 3006,romanian
# 3007,hungarian
# 3008,maori
# 3009,french
# 3010,french
# 3011,french
# 3012,french
# 3013,romanian
# 3014,finnish
# 3015,portuguese
# 3016,norwegian
# 3017,german
# 3018,maori
# 3019,french
# 3020,german
# 3021,vietnamese
# 3022,vietnamese
# 3023,french
# 3024,albanian
# 3025,hungarian
# 3026,finnish
# 3027,esperanto
# 3028,albanian
# 3029,norwegian
# 3030,turkish
# 3031,esperanto
# 3032,english
# 3033,italian
# 3034,esperanto
# 3035,vietnamese
# 3036,english
# 3037,hungarian
# 3038,lithuanian
# 3039,italian
# 3040,hungarian
# 3041,vietnamese
# 3042,portuguese
# 3043,portuguese
# 3044,czech
# 3045,lithuanian
# 3046,norwegian
# 3047,lithuanian
# 3048,hungarian
# 3049,hungarian
# 3050,italian
# 3051,maori
# 3052,lithuanian
# 3053,xhosa
# 3054,albanian
# 3055,norwegian
# 3056,finnish
# 3057,french
# 3058,swedish
# 3059,turkish
# 3060,vietnamese
# 3061,vietnamese
# 3062,german
# 3063,romanian
# 3064,czech
# 3065,turkish
# 3066,maori
# 3067,esperanto
# 3068,czech
# 3069,vietnamese
# 3070,finnish
# 3071,finnish
# 3072,lithuanian
# 3073,norwegian
# 3074,portuguese
# 3075,swedish
# 3076,maori
# 3077,xhosa
# 3078,norwegian
# 3079,turkish
# 3080,romanian
# 3081,xhosa
# 3082,english
# 3083,portuguese
# 3084,maori
# 3085,turkish
# 3086,czech
# 3087,xhosa
# 3088,swedish
# 3089,xhosa
# 3090,swedish
# 3091,albanian
# 3092,xhosa
# 3093,hungarian
# 3094,swedish
# 3095,norwegian
# 3096,danish
# 3097,italian
# 3098,lithuanian
# 3099,xhosa
# 3100,esperanto
# 3101,vietnamese
# 3102,xhosa
# 3103,italian
# 3104,maori
# 3105,lithuanian
# 3106,english
# 3107,lithuanian
# 3108,lithuanian
# 3109,french
# 3110,danish
# 3111,norwegian
# 3112,czech
# 3113,swedish
# 3114,finnish
# 3115,xhosa
# 3116,esperanto
# 3117,italian
# 3118,portuguese
# 3119,english
# 3120,albanian
# 3121,swedish
# 3122,lithuanian
# 3123,albanian
# 3124,maori
# 3125,norwegian
# 3126,albanian
# 3127,maori
# 3128,german
# 3129,hungarian
# 3130,esperanto
# 3131,german
# 3132,norwegian
# 3133,hungarian
# 3134,portuguese
# 3135,romanian
# 3136,english
# 3137,german
# 3138,spanish
# 3139,swedish
# 3140,maori
# 3141,romanian
# 3142,swedish
# 3143,esperanto
# 3144,swedish
# 3145,czech
# 3146,french
# 3147,hungarian
# 3148,albanian
# 3149,portuguese
# 3150,xhosa
# 3151,xhosa
# 3152,esperanto
# 3153,italian
# 3154,turkish
# 3155,german
# 3156,turkish
# 3157,norwegian
# 3158,maori
# 3159,esperanto
# 3160,xhosa
# 3161,norwegian
# 3162,lithuanian
# 3163,albanian
# 3164,turkish
# 3165,albanian
# 3166,hungarian
# 3167,maori
# 3168,french
# 3169,xhosa
# 3170,english
# 3171,italian
# 3172,spanish
# 3173,vietnamese
# 3174,xhosa
# 3175,czech
# 3176,esperanto
# 3177,english
# 3178,norwegian
# 3179,norwegian
# 3180,vietnamese
# 3181,italian
# 3182,english
# 3183,romanian
# 3184,romanian
# 3185,esperanto
# 3186,swedish
# 3187,norwegian
# 3188,english
# 3189,swedish
# 3190,hungarian
# 3191,lithuanian
# 3192,vietnamese
# 3193,czech
# 3194,french
# 3195,french
# 3196,vietnamese
# 3197,portuguese
# 3198,english
# 3199,xhosa
# 3200,maori
# 3201,english
# 3202,danish
# 3203,norwegian
# 3204,italian
# 3205,vietnamese
# 3206,italian
# 3207,romanian
# 3208,turkish
# 3209,german
# 3210,german
# 3211,maori
# 3212,swedish
# 3213,spanish
# 3214,portuguese
# 3215,xhosa
# 3216,turkish
# 3217,german
# 3218,esperanto
# 3219,german
# 3220,esperanto
# 3221,italian
# 3222,lithuanian
# 3223,english
# 3224,romanian
# 3225,italian
# 3226,xhosa
# 3227,english
# 3228,albanian
# 3229,spanish
# 3230,xhosa
# 3231,swedish
# 3232,portuguese
# 3233,albanian
# 3234,german
# 3235,italian
# 3236,albanian
# 3237,portuguese
# 3238,vietnamese
# 3239,maori
# 3240,spanish
# 3241,portuguese
# 3242,vietnamese
# 3243,xhosa
# 3244,xhosa
# 3245,german
# 3246,turkish
# 3247,spanish
# 3248,italian
# 3249,lithuanian
# 3250,vietnamese
# 3251,vietnamese
# 3252,hungarian
# 3253,swedish
# 3254,spanish
# 3255,finnish
# 3256,norwegian
# 3257,norwegian
# 3258,norwegian
# 3259,romanian
# 3260,finnish
# 3261,french
# 3262,italian
# 3263,hungarian
# 3264,danish
# 3265,italian
# 3266,swedish
# 3267,spanish
# 3268,italian
# 3269,esperanto
# 3270,danish
# 3271,albanian
# 3272,finnish
# 3273,norwegian
# 3274,vietnamese
# 3275,lithuanian
# 3276,turkish
# 3277,maori
# 3278,xhosa
# 3279,hungarian
# 3280,spanish
# 3281,vietnamese
# 3282,xhosa
# 3283,hungarian
# 3284,romanian
# 3285,italian
# 3286,xhosa
# 3287,vietnamese
# 3288,german
# 3289,spanish
# 3290,xhosa
# 3291,hungarian
# 3292,german
# 3293,italian
# 3294,german
# 3295,vietnamese
# 3296,portuguese
# 3297,vietnamese
# 3298,portuguese
# 3299,norwegian
# 3300,esperanto
# 3301,german
# 3302,portuguese
# 3303,hungarian
# 3304,french
# 3305,spanish
# 3306,hungarian
# 3307,czech
# 3308,maori
# 3309,finnish
# 3310,danish
# 3311,lithuanian
# 3312,lithuanian
# 3313,lithuanian
# 3314,finnish
# 3315,english
# 3316,lithuanian
# 3317,portuguese
# 3318,norwegian
# 3319,norwegian
# 3320,portuguese
# 3321,lithuanian
# 3322,spanish
# 3323,lithuanian
# 3324,romanian
# 3325,lithuanian
# 3326,lithuanian
# 3327,german
# 3328,swedish
# 3329,english
# 3330,norwegian
# 3331,albanian
# 3332,esperanto
# 3333,maori
# 3334,hungarian
# 3335,vietnamese
# 3336,norwegian
# 3337,spanish
# 3338,lithuanian
# 3339,german
# 3340,czech
# 3341,swedish
# 3342,hungarian
# 3343,albanian
# 3344,romanian
# 3345,portuguese
# 3346,danish
# 3347,portuguese
# 3348,danish
# 3349,czech
# 3350,finnish
# 3351,spanish
# 3352,esperanto
# 3353,czech
# 3354,esperanto
# 3355,xhosa
# 3356,albanian
# 3357,maori
# 3358,portuguese
# 3359,english
# 3360,swedish
# 3361,english
# 3362,maori
# 3363,czech
# 3364,finnish
# 3365,czech
# 3366,vietnamese
# 3367,finnish
# 3368,swedish
# 3369,german
# 3370,danish
# 3371,portuguese
# 3372,maori
# 3373,lithuanian
# 3374,english
# 3375,czech
# 3376,italian
# 3377,french
# 3378,swedish
# 3379,maori
# 3380,vietnamese
# 3381,romanian
# 3382,vietnamese
# 3383,romanian
# 3384,danish
# 3385,italian
# 3386,portuguese
# 3387,english
# 3388,czech
# 3389,maori
# 3390,turkish
# 3391,norwegian
# 3392,finnish
# 3393,italian
# 3394,hungarian
# 3395,romanian
# 3396,turkish
# 3397,maori
# 3398,turkish
# 3399,romanian
# 3400,albanian
# 3401,lithuanian
# 3402,hungarian
# 3403,albanian
# 3404,albanian
# 3405,spanish
# 3406,vietnamese
# 3407,spanish
# 3408,swedish
# 3409,czech
# 3410,italian
# 3411,xhosa
# 3412,romanian
# 3413,hungarian
# 3414,swedish
# 3415,finnish
# 3416,swedish
# 3417,vietnamese
# 3418,romanian
# 3419,swedish
# 3420,xhosa
# 3421,czech
# 3422,esperanto
# 3423,czech
# 3424,romanian
# 3425,hungarian
# 3426,xhosa
# 3427,hungarian
# 3428,maori
# 3429,xhosa
# 3430,italian
# 3431,esperanto
# 3432,german
# 3433,english
# 3434,turkish
# 3435,maori
# 3436,finnish
# 3437,turkish
# 3438,italian
# 3439,spanish
# 3440,hungarian
# 3441,czech
# 3442,turkish
# 3443,xhosa
# 3444,portuguese
# 3445,italian
# 3446,romanian
# 3447,vietnamese
# 3448,lithuanian
# 3449,albanian
# 3450,romanian
# 3451,esperanto
# 3452,french
# 3453,norwegian
# 3454,albanian
# 3455,hungarian
# 3456,english
# 3457,italian
# 3458,vietnamese
# 3459,portuguese
# 3460,norwegian
# 3461,turkish
# 3462,maori
# 3463,norwegian
# 3464,german
# 3465,german
# 3466,xhosa
# 3467,romanian
# 3468,italian
# 3469,maori
# 3470,swedish
# 3471,hungarian
# 3472,norwegian
# 3473,xhosa
# 3474,english
# 3475,hungarian
# 3476,hungarian
# 3477,xhosa
# 3478,danish
# 3479,norwegian
# 3480,xhosa
# 3481,portuguese
# 3482,portuguese
# 3483,french
# 3484,swedish
# 3485,french
# 3486,swedish
# 3487,danish
# 3488,italian
# 3489,vietnamese
# 3490,french
# 3491,italian
# 3492,swedish
# 3493,danish
# 3494,romanian
# 3495,portuguese
# 3496,norwegian
# 3497,hungarian
# 3498,maori
# 3499,swedish
# 3500,vietnamese
# 3501,english
# 3502,hungarian
# 3503,finnish
# 3504,spanish
# 3505,esperanto
# 3506,english
# 3507,english
# 3508,maori
# 3509,hungarian
# 3510,norwegian
# 3511,hungarian
# 3512,german
# 3513,portuguese
# 3514,hungarian
# 3515,portuguese
# 3516,german
# 3517,albanian
# 3518,german
# 3519,swedish
# 3520,lithuanian
# 3521,portuguese
# 3522,esperanto
# 3523,romanian
# 3524,french
# 3525,turkish
# 3526,portuguese
# 3527,german
# 3528,xhosa
# 3529,romanian
# 3530,albanian
# 3531,romanian
# 3532,turkish
# 3533,albanian
# 3534,finnish
# 3535,spanish
# 3536,english
# 3537,xhosa
# 3538,french
# 3539,lithuanian
# 3540,italian
# 3541,portuguese
# 3542,czech
# 3543,turkish
# 3544,german
# 3545,spanish
# 3546,xhosa
# 3547,italian
# 3548,esperanto
# 3549,albanian
# 3550,turkish
# 3551,albanian
# 3552,hungarian
# 3553,czech
# 3554,xhosa
# 3555,finnish
# 3556,french
# 3557,maori
# 3558,hungarian
# 3559,esperanto
# 3560,albanian
# 3561,french
# 3562,french
# 3563,finnish
# 3564,portuguese
# 3565,norwegian
# 3566,romanian
# 3567,german
# 3568,finnish
# 3569,portuguese
# 3570,albanian
# 3571,french
# 3572,swedish
# 3573,romanian
# 3574,norwegian
# 3575,vietnamese
# 3576,albanian
# 3577,vietnamese
# 3578,portuguese
# 3579,vietnamese
# 3580,esperanto
# 3581,xhosa
# 3582,xhosa
# 3583,italian
# 3584,danish
# 3585,lithuanian
# 3586,maori
# 3587,portuguese
# 3588,hungarian
# 3589,norwegian
# 3590,english
# 3591,romanian
# 3592,hungarian
# 3593,norwegian
# 3594,xhosa
# 3595,esperanto
# 3596,xhosa
# 3597,spanish
# 3598,finnish
# 3599,portuguese
# 3600,french
# 3601,english
# 3602,english
# 3603,finnish
# 3604,lithuanian
# 3605,german
# 3606,vietnamese
# 3607,albanian
# 3608,german
# 3609,vietnamese
# 3610,czech
# 3611,maori
# 3612,german
# 3613,french
# 3614,turkish
# 3615,danish
# 3616,norwegian
# 3617,romanian
# 3618,norwegian
# 3619,norwegian
# 3620,swedish
# 3621,esperanto
# 3622,xhosa
# 3623,esperanto
# 3624,french
# 3625,xhosa
# 3626,albanian
# 3627,turkish
# 3628,french
# 3629,italian
# 3630,german
# 3631,english
# 3632,german
# 3633,norwegian
# 3634,finnish
# 3635,portuguese
# 3636,hungarian
# 3637,vietnamese
# 3638,romanian
# 3639,turkish
# ...
# 3808,italian
# 3809,german
# 3810,xhosa
# 3811,spanish
# 3812,czech
# 3813,portuguese
# 3814,albanian
# 3815,finnish
# 3816,vietnamese
# 3817,german
# 3818,german
# 3819,english
# 3820,romanian
# 3821,romanian
# 3822,french
# 3823,finnish
# 3824,turkish
# 3825,romanian
# 3826,italian
# 3827,danish
# 3828,romanian
# 3829,maori
# 3830,turkish
# 3831,norwegian
# 3832,albanian
# 3833,portuguese
# 3834,portuguese
# 3835,maori
# 3836,turkish
# 3837,spanish
# 3838,romanian
# 3839,spanish
# 3840,german
# 3841,french
# 3842,spanish
# 3843,portuguese
# 3844,italian
# 3845,albanian
# 3846,esperanto
# 3847,swedish
# 3848,maori
# 3849,xhosa
# 3850,turkish
# 3851,xhosa
# 3852,german
# 3853,danish
# 3854,finnish
# 3855,english
# 3856,swedish
# 3857,spanish
# 3858,english
# 3859,finnish
# 3860,turkish
# 3861,portuguese
# 3862,portuguese
# 3863,albanian
# 3864,french
# 3865,french
# 3866,esperanto
# 3867,english
# 3868,vietnamese
# 3869,french
# 3870,italian
# 3871,french
# 3872,italian
# 3873,xhosa
# 3874,romanian
# 3875,italian
# 3876,swedish
# 3877,turkish
# 3878,maori
# 3879,turkish
# 3880,portuguese
# 3881,romanian
# 3882,spanish
# 3883,czech
# 3884,xhosa
# 3885,italian
# 3886,maori
# 3887,turkish
# 3888,italian
# 3889,turkish
# 3890,czech
# 3891,german
# 3892,xhosa
# 3893,italian
# 3894,esperanto
# 3895,spanish
# 3896,german
# 3897,esperanto
# 3898,finnish
# 3899,danish
# 3900,german
# 3901,french
# 3902,norwegian
# 3903,french
# 3904,finnish
# 3905,turkish
# 3906,portuguese
# 3907,xhosa
# 3908,albanian
# 3909,french
# 3910,french
# 3911,xhosa
# 3912,czech
# 3913,english
# 3914,danish
# 3915,lithuanian
# 3916,vietnamese
# 3917,maori
# 3918,finnish
# 3919,xhosa
# 3920,vietnamese
# 3921,portuguese
# 3922,albanian
# 3923,lithuanian
# 3924,english
# 3925,spanish
# 3926,turkish
# 3927,french
# 3928,norwegian
# 3929,maori
# 3930,portuguese
# 3931,romanian
# 3932,turkish
# 3933,swedish
# 3934,norwegian
# 3935,xhosa
# 3936,english
# 3937,finnish
# 3938,french
# 3939,italian
# 3940,swedish
# 3941,italian
# 3942,esperanto
# 3943,swedish
# 3944,german
# 3945,english
# 3946,vietnamese
# 3947,swedish
# 3948,portuguese
# 3949,turkish
# 3950,finnish
# 3951,romanian
# 3952,romanian
# 3953,esperanto
# 3954,albanian
# 3955,czech
# 3956,czech
# 3957,danish
# 3958,xhosa
# 3959,danish
# 3960,danish
# 3961,german
# 3962,german
# 3963,lithuanian
# 3964,swedish
# 3965,french
# 3966,english
# 3967,norwegian
# 3968,xhosa
# 3969,spanish
# 3970,finnish
# 3971,maori
# 3972,spanish
# 3973,norwegian
# 3974,norwegian
# 3975,czech
# 3976,german
# 3977,german
# 3978,spanish
# 3979,turkish
# 3980,hungarian
# 3981,albanian
# 3982,finnish
# 3983,danish
# 3984,esperanto
# 3985,spanish
# 3986,italian
# 3987,vietnamese
# 3988,portuguese
# 3989,german
# 3990,danish
# 3991,xhosa
# 3992,norwegian
# 3993,swedish
# 3994,esperanto
# 3995,vietnamese
# 3996,swedish
# 3997,xhosa
# 3998,norwegian
# 3999,vietnamese
# 4000,norwegian
# 4001,vietnamese
# 4002,hungarian
# 4003,norwegian
# 4004,turkish
# 4005,english
# 4006,spanish
# 4007,french
# 4008,english
# 4009,german
# 4010,spanish
# 4011,romanian
# 4012,vietnamese
# 4013,german
# 4014,portuguese
# 4015,french
# 4016,german
# 4017,maori
# 4018,czech
# 4019,lithuanian
# 4020,portuguese
# 4021,romanian
# 4022,vietnamese
# 4023,italian
# 4024,swedish
# 4025,english
# 4026,danish
# 4027,french
# 4028,norwegian
# 4029,english
# 4030,norwegian
# 4031,danish
# 4032,italian
# 4033,portuguese
# 4034,danish
# 4035,esperanto
# 4036,albanian
# 4037,hungarian
# 4038,finnish
# 4039,danish
# 4040,albanian
# 4041,english
# 4042,xhosa
# 4043,spanish
# 4044,portuguese
# 4045,italian
# 4046,finnish
# 4047,italian
# 4048,swedish
# 4049,albanian
# 4050,xhosa
# 4051,danish
# 4052,romanian
# 4053,norwegian
# 4054,german
# 4055,french
# 4056,finnish
# 4057,romanian
# 4058,french
# 4059,finnish
# 4060,italian
# 4061,romanian
# 4062,swedish
# 4063,german
# 4064,turkish
# 4065,italian
# 4066,esperanto
# 4067,lithuanian
# 4068,german
# 4069,portuguese
# 4070,turkish
# 4071,german
# 4072,hungarian
# 4073,albanian
# 4074,italian
# 4075,german
# 4076,lithuanian
# 4077,albanian
# 4078,finnish
# 4079,lithuanian
# 4080,esperanto
# 4081,german
# 4082,xhosa
# 4083,czech
# 4084,lithuanian
# 4085,norwegian
# 4086,vietnamese
# 4087,portuguese
# 4088,czech
# 4089,romanian
# 4090,vietnamese
# 4091,finnish
# 4092,hungarian
# 4093,french
# 4094,swedish
# 4095,spanish
# 4096,vietnamese
# 4097,romanian
# 4098,czech
# 4099,german
# 4100,albanian
# 4101,maori
# 4102,spanish
# 4103,albanian
# 4104,hungarian
# 4105,swedish
# 4106,hungarian
# 4107,lithuanian
# 4108,romanian
# 4109,german
# 4110,vietnamese
# 4111,xhosa
# 4112,german
# 4113,french
# 4114,czech
# 4115,czech
# 4116,danish
# 4117,romanian
# 4118,portuguese
# 4119,hungarian
# 4120,finnish
# 4121,spanish
# 4122,english
# 4123,french
# 4124,vietnamese
# 4125,italian
# 4126,german
# 4127,english
# 4128,german
# 4129,italian
# 4130,swedish
# 4131,czech
# 4132,swedish
# 4133,maori
# 4134,esperanto
# 4135,turkish
# 4136,portuguese
# 4137,albanian
# 4138,hungarian
# 4139,swedish
# 4140,xhosa
# 4141,swedish
# 4142,esperanto
# 4143,italian
# 4144,lithuanian
# 4145,xhosa
# 4146,portuguese
# 4147,french
# 4148,hungarian
# 4149,turkish
# 4150,german
# 4151,french
# 4152,portuguese
# 4153,portuguese
# 4154,xhosa
# 4155,portuguese
# 4156,portuguese
# 4157,maori
# 4158,czech
# 4159,italian
# 4160,xhosa
# 4161,maori
# 4162,hungarian
# 4163,finnish
# 4164,french
# 4165,french
# 4166,czech
# 4167,english
# 4168,finnish
# 4169,german
# 4170,albanian
# 4171,english
# 4172,maori
# 4173,danish
# 4174,esperanto
# 4175,italian
# 4176,romanian
# 4177,french
# 4178,spanish
# 4179,czech
# 4180,finnish
# 4181,italian
# 4182,czech
# 4183,spanish
# 4184,albanian
# 4185,vietnamese
# 4186,hungarian
# 4187,german
# 4188,czech
# 4189,vietnamese
# 4190,esperanto
# 4191,french
# 4192,lithuanian
# 4193,lithuanian
# 4194,norwegian
# 4195,portuguese
# 4196,albanian
# 4197,hungarian
# 4198,finnish
# 4199,xhosa
# 4200,lithuanian
# 4201,spanish
# 4202,portuguese
# 4203,french
# 4204,maori
# 4205,spanish
# 4206,turkish
# 4207,english
# 4208,maori
# 4209,czech
# 4210,english
# 4211,spanish
# 4212,hungarian
# 4213,italian
# 4214,english
# 4215,romanian
# 4216,danish
# 4217,maori
# 4218,czech
# 4219,german
# 4220,german
# 4221,norwegian
# 4222,czech
# 4223,german
# 4224,swedish
# 4225,turkish
# 4226,english
# 4227,romanian
# 4228,english
# 4229,spanish
# 4230,esperanto
# 4231,czech
# 4232,czech
# 4233,esperanto
# 4234,hungarian
# 4235,xhosa
# 4236,czech
# 4237,spanish
# 4238,english
# 4239,esperanto
# 4240,finnish
# 4241,xhosa
# 4242,portuguese
# 4243,english
# 4244,lithuanian
# 4245,french
# 4246,romanian
# 4247,albanian
# 4248,czech
# 4249,spanish
# 4250,turkish
# 4251,french
# 4252,albanian
# 4253,portuguese
# 4254,esperanto
# 4255,esperanto
# 4256,czech
# 4257,maori
# 4258,norwegian
# 4259,hungarian
# 4260,romanian
# 4261,spanish
# 4262,maori
# 4263,czech
# 4264,czech
# 4265,danish
# 4266,swedish
# 4267,xhosa
# 4268,esperanto
# 4269,italian
# 4270,spanish
# 4271,norwegian
# 4272,finnish
# 4273,albanian
# 4274,swedish
# 4275,italian
# 4276,esperanto
# 4277,spanish
# 4278,german
# 4279,vietnamese
# 4280,vietnamese
# 4281,xhosa
# 4282,albanian
# 4283,romanian
# 4284,vietnamese
# 4285,vietnamese
# 4286,turkish
# 4287,danish
# 4288,swedish
# 4289,maori
# 4290,hungarian
# 4291,french
# 4292,hungarian
# 4293,french
# 4294,esperanto
# 4295,german
# 4296,swedish
# 4297,norwegian
# 4298,italian
# 4299,turkish
# 4300,turkish
# 4301,maori
# 4302,finnish
# 4303,romanian
# 4304,maori
# 4305,czech
# 4306,czech
# 4307,esperanto
# 4308,turkish
# 4309,romanian
# 4310,czech
# 4311,spanish
# 4312,finnish
# 4313,albanian
# 4314,english
# 4315,english
# 4316,xhosa
# 4317,spanish
# 4318,norwegian
# 4319,xhosa
# 4320,spanish
# 4321,english
# 4322,italian
# 4323,finnish
# 4324,romanian
# 4325,albanian
# 4326,czech
# 4327,czech
# 4328,esperanto
# 4329,english
# 4500,swedish
# 4501,italian
# 4502,english
# 4503,norwegian
# 4504,turkish
# 4505,lithuanian
# 4506,esperanto
# 4507,vietnamese
# 4508,portuguese
# 4509,romanian
# 4510,albanian
# 4511,french
# 4512,french
# 4513,xhosa
# 4514,french
# 4515,spanish
# 4516,xhosa
# 4517,turkish
# 4518,spanish
# 4519,turkish
# 4520,finnish
# 4521,xhosa
# 4522,maori
# 4523,albanian
# 4524,turkish
# 4525,romanian
# 4526,danish
# 4527,romanian
# 4528,romanian
# 4529,english
# 4530,vietnamese
# 4531,xhosa
# 4532,romanian
# 4533,romanian
# 4534,czech
# 4535,albanian
# 4536,portuguese
# 4537,lithuanian
# 4538,english
# 4539,spanish
# 4540,norwegian
# 4541,spanish
# 4542,vietnamese
# 4543,norwegian
# 4544,lithuanian
# 4545,romanian
# 4546,danish
# 4547,xhosa
# 4548,esperanto
# 4549,french
# 4550,maori
# 4551,swedish
# 4552,norwegian
# 4553,czech
# 4554,swedish
# 4555,hungarian
# 4556,german
# 4557,turkish
# 4558,spanish
# 4559,finnish
# 4560,turkish
# 4561,turkish
# 4562,xhosa
# 4563,english
# 4564,finnish
# 4565,french
# 4566,english
# 4567,lithuanian
# 4568,norwegian
# 4569,portuguese
# 4570,finnish
# 4571,czech
# 4572,vietnamese
# 4573,vietnamese
# 4574,spanish
# 4575,norwegian
# 4576,romanian
# 4577,albanian
# 4578,czech
# 4579,lithuanian
# 4580,italian
# 4581,portuguese
# 4582,norwegian
# 4583,albanian
# 4584,finnish
# 4585,esperanto
# 4586,xhosa
# 4587,romanian
# 4588,xhosa
# 4589,lithuanian
# 4590,swedish
# 4591,english
# 4592,swedish
# 4593,finnish
# 4594,finnish
# 4595,spanish
# 4596,finnish
# 4597,portuguese
# 4598,danish
# 4599,finnish
# 4600,czech
# 4601,maori
# 4602,italian
# 4603,hungarian
# 4604,esperanto
# 4605,romanian
# 4606,hungarian
# 4607,xhosa
# 4608,portuguese
# 4609,danish
# 4610,finnish
# 4611,vietnamese
# 4612,english
# 4613,czech
# 4614,albanian
# 4615,czech
# 4616,norwegian
# 4617,german
# 4618,italian
# 4619,finnish
# 4620,romanian
# 4621,hungarian
# 4622,portuguese
# 4623,hungarian
# 4624,turkish
# 4625,english
# 4626,english
# 4627,finnish
# 4628,french
# 4629,norwegian
# 4630,portuguese
# 4631,finnish
# 4632,xhosa
# 4633,finnish
# 4634,swedish
# 4635,czech
# 4636,czech
# 4637,german
# 4638,norwegian
# 4639,czech
# 4640,romanian
# 4641,albanian
# 4642,norwegian
# 4643,albanian
# 4644,xhosa
# 4645,norwegian
# 4646,albanian
# 4647,spanish
# 4648,maori
# 4649,romanian
# 4650,romanian
# 4651,vietnamese
# 4652,norwegian
# 4653,norwegian
# 4654,german
# 4655,albanian
# 4656,turkish
# 4657,finnish
# 4658,french
# 4659,romanian
# 4660,maori
# 4661,vietnamese
# 4662,vietnamese
# 4663,turkish
# 4664,turkish
# 4665,english
# 4666,italian
# 4667,vietnamese
# 4668,norwegian
# 4669,hungarian
# 4670,czech
# 4671,german
# 4672,lithuanian
# 4673,portuguese
# 4674,vietnamese
# 4675,portuguese
# 4676,spanish
# 4677,vietnamese
# 4678,esperanto
# 4679,finnish
# 4680,portuguese
# 4681,xhosa
# 4682,spanish
# 4683,esperanto
# 4684,turkish
# 4685,english
# 4686,italian
# 4687,hungarian
# 4688,swedish
# 4689,romanian
# 4690,spanish
# 4691,norwegian
# 4692,swedish
# 4693,portuguese
# 4694,albanian
# 4695,finnish
# 4696,vietnamese
# 4697,lithuanian
# 4698,lithuanian
# 4699,english
# 4700,german
# 4701,french
# 4702,portuguese
# 4703,german
# 4704,swedish
# 4705,esperanto
# 4706,swedish
# 4707,albanian
# 4708,german
# 4709,norwegian
# 4710,romanian
# 4711,xhosa
# 4712,italian
# 4713,danish
# 4714,finnish
# 4715,swedish
# 4716,esperanto
# 4717,finnish
# 4718,xhosa
# 4719,spanish
# 4720,czech
# 4721,xhosa
# 4722,english
# 4723,czech
# 4724,italian
# 4725,french
# 4726,hungarian
# 4727,english
# 4728,portuguese
# 4729,czech
# 4730,german
# 4731,finnish
# 4732,spanish
# 4733,swedish
# 4734,romanian
# 4735,albanian
# 4736,italian
# 4737,italian
# 4738,finnish
# 4739,portuguese
# 4740,german
# 4741,romanian
# 4742,maori
# 4743,albanian
# 4744,esperanto
# 4745,finnish
# 4746,portuguese
# 4747,albanian
# 4748,albanian
# 4749,norwegian
# 4750,italian
# 4751,portuguese
# 4752,english
# 4753,vietnamese
# 4754,swedish
# 4755,xhosa
# 4756,german
# 4757,portuguese
# 4758,danish
# 4759,french
# 4760,albanian
# 4761,swedish
# 4762,hungarian
# 4763,albanian
# 4764,portuguese
# 4765,albanian
# 4766,esperanto
# 4767,lithuanian
# 4768,romanian
# 4769,vietnamese
# 4770,romanian
# 4771,norwegian
# 4772,french
# 4773,turkish
# 4774,swedish
# 4775,english
# 4776,german
# 4777,german
# 4778,finnish
# 4779,albanian
# 4780,czech
# 4781,hungarian
# 4782,romanian
# 4783,danish
# 4784,danish
# 4785,esperanto
# 4786,norwegian
# 4787,turkish
# 4788,lithuanian
# 4789,french
# 4790,romanian
# 4791,finnish
# 4792,norwegian
# 4793,xhosa
# 4794,turkish
# 4795,english
# 4796,spanish
# 4797,maori
# 4798,albanian
# 4799,finnish
# 4800,esperanto
# 4801,czech
# 4802,turkish
# 4803,esperanto
# 4804,danish
# 4805,portuguese
# 4806,spanish
# 4807,czech
# 4808,french
# 4809,albanian
# 4810,hungarian
# 4811,english
# 4812,german
# 4813,italian
# 4814,spanish
# 4815,czech
# 4816,italian
# 4817,romanian
# 4818,english
# 4819,french
# 4820,romanian
# 4821,italian
# 4822,swedish
# 4823,french
# 4824,danish
# 4825,english
# 4826,english
# 4827,spanish
# 4828,romanian
# 4829,french
# 4830,esperanto
# 4831,norwegian
# 4832,german
# 4833,lithuanian
# 4834,hungarian
# 4835,finnish
# 4836,vietnamese
# 4837,esperanto
# 4838,italian
# 4839,italian
# 4840,maori
# 4841,spanish
# 4842,hungarian
# 4843,portuguese
# 4844,romanian
# 4845,finnish
# 4846,portuguese
# 4847,german
# 4848,lithuanian
# 4849,norwegian
# 4850,finnish
# 4851,esperanto
# 4852,english
# 4853,maori
# 4854,vietnamese
# 4855,maori
# 4856,xhosa
# 4857,german
# 4858,norwegian
# 4859,turkish
# 4860,spanish
# 4861,lithuanian
# 4862,turkish
# 4863,turkish
# 4864,portuguese
# 4865,romanian
# 4866,german
# 4867,english
# 4868,maori
# 4869,danish
# 4870,english
# 4871,lithuanian
# 4872,norwegian
# 4873,albanian
# 4874,albanian
# 4875,esperanto
# 4876,portuguese
# 4877,spanish
# 4878,portuguese
# 4879,romanian
# 4880,xhosa
# 4881,hungarian
# 4882,italian
# 4883,czech
# 4884,romanian
# 4885,norwegian
# 4886,turkish
# 4887,spanish
# 4888,vietnamese
# 4889,spanish
# 4890,portuguese
# 4891,italian
# 4892,norwegian
# 4893,vietnamese
# 4894,swedish
# 4895,hungarian
# 4896,spanish
# 4897,italian
# 4898,swedish
# 4899,esperanto
# 4900,vietnamese
# 4901,lithuanian
# 4902,turkish
# 4903,spanish
# 4904,lithuanian
# 4905,spanish
# 4906,italian
# 4907,czech
# 4908,finnish
# 4909,xhosa
# 4910,albanian
# 4911,norwegian
# 4912,italian
# 4913,italian
# 4914,french
# 4915,albanian
# 4916,german
# 4917,finnish
# 4918,romanian
# 4919,esperanto
# 4920,swedish
# 4921,portuguese
# 4922,spanish
# 4923,finnish
# 4924,portuguese
# 4925,swedish
# 4926,italian
# 4927,finnish
# 4928,italian
# 4929,lithuanian
# 4930,vietnamese
# 4931,czech
# 4932,xhosa
# 4933,xhosa
# 4934,esperanto
# 4935,maori
# 4936,norwegian
# 4937,hungarian
# 4938,czech
# 4939,romanian
# 4940,vietnamese
# 4941,italian
# 4942,norwegian
# 4943,finnish
# 4944,italian
# 4945,turkish
# 4946,czech
# 4947,esperanto
# 4948,romanian
# 4949,norwegian
# 4950,maori
# 4951,danish
# 4952,english
# 4953,swedish
# 4954,german
# 4955,swedish
# 4956,romanian
# 4957,portuguese
# 4958,french
# 4959,vietnamese
# 4960,german
# 4961,turkish
# 4962,romanian
# 4963,english
# 4964,romanian
# 4965,maori
# 4966,xhosa
# 4967,romanian
# 4968,german
# 4969,maori
# 4970,xhosa
# 4971,portuguese
# 4972,danish
# 4973,lithuanian
# 4974,turkish
# 4975,vietnamese
# 4976,english
# 4977,french
# 4978,norwegian
# 4979,czech
# 4980,hungarian
# 4981,romanian
# 4982,esperanto
# 4983,maori
# 4984,czech
# 4985,esperanto
# 4986,albanian
# 4987,spanish
# 4988,albanian
# 4989,albanian
# 4990,english
# 4991,xhosa
# 4992,swedish
# 4993,german
# 4994,portuguese
# 4995,swedish
# 4996,english
# 4997,italian
# 4998,italian
# 4999,romanian
# 5000,swedish

# %%
# torch.save(rnn.state_dict(), './rnn_classifier.pth')
"""
chunk_len = 50

BATCH_SIZE = 128
# n_epochs = 2000
hidden_size = 128
n_layers = 2
# n_layers = 1
# learning_rate = 0.01
model_type = 'gru'
rnn = RNN(n_letters, hidden_size, n_languages, model_type=model_type, n_layers=n_layers).to(device)
"""
